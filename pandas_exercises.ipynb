# %%
import pandas as pd

# %%
# Import pandas library
import pandas as pd

# Creating the Series from a list
cat1 = ['Grumpy Cat', 'cat', 2012]
ser = pd.Series(cat1)

# Create the index
cat_index = ['name', 'species', 'YOB']

# Set the index
ser.index = cat_index

# %%
ser
# Out:
# name       Grumpy Cat
# species           cat
# YOB              2012
# dtype: object

# %%
# Creating a DataFrame from a list
name = ['Grumpy Cat', 'Garfi the Angry Cat', 'Colonel Meow']
species = ['cat','cat', 'cat']
YOB = [2004, 2012, 2011]

# Creating the Series from a dictionary
cat_dict= {	'name':name,
   	        'species':species, 
            'YOB': YOB}
df = pd.DataFrame(cat_dict)
df
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
df["name"]
# Out:
# 0             Grumpy Cat
# 1    Garfi the Angry Cat
# 2           Colonel Meow
# Name: name, dtype: object

# %%
df["species"]
# Out:
# 0    cat
# 1    cat
# 2    cat
# Name: species, dtype: object

# %%
df["YOB"]
# Out:
# 0    2004
# 1    2012
# 2    2011
# Name: YOB, dtype: int64

# %%
df[["YOB", "name"]]
# Out:
#     YOB                 name
# 0  2004           Grumpy Cat
# 1  2012  Garfi the Angry Cat
# 2  2011         Colonel Meow

# %%
df[["name", "species"]]
# Out:
#                   name species
# 0           Grumpy Cat     cat
# 1  Garfi the Angry Cat     cat
# 2         Colonel Meow     cat

# %%
df
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
df[0:2]
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012

# %%
df[0:1]
# Out:
#          name species   YOB
# 0  Grumpy Cat     cat  2004

# %%
df[0:3]
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
 df.loc[0:2,["name","species"]]
# Out:
#                   name species
# 0           Grumpy Cat     cat
# 1  Garfi the Angry Cat     cat
# 2         Colonel Meow     cat

# %%
df.loc[0:1, ["YOB", "species"]]
# Out:
#     YOB species
# 0  2004     cat
# 1  2012     cat

# %%
df.iloc[0:1,:]
# Out:
#          name species   YOB
# 0  Grumpy Cat     cat  2004

# %%
df.iloc[0:1, 0:1]
# Out:
#          name
# 0  Grumpy Cat

# %%
df.iloc[0:1, 0:2]
# Out:
#          name species
# 0  Grumpy Cat     cat

# %%
movies = pd.read_csv("./movies_2.csv")

# %%
movies
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
movies.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
movies.head(3)
# Out:
#    MovieID               Title MPAA Rating      Budget        Gross  \
# 0        1  Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2  Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3      Turner & Hooch          PG  13000000.0   71079915.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...

# %%
movies.head(19)
# Out:
#     MovieID                                  Title MPAA Rating      Budget  \
# 0         1                     Look Who's Talking       PG-13   7500000.0
# 1         2                     Driving Miss Daisy          PG   7500000.0
# 2         3                         Turner & Hooch          PG  13000000.0
# 3         4             Born on the Fourth of July           R  14000000.0
# 4         5                        Field of Dreams          PG  15000000.0
# 5         6                             Uncle Buck          PG  15000000.0
# 6         7                When Harry Met Sally...           R  16000000.0
# 7         8                     Dead Poets Society          PG  16400000.0
# 8         9                             Parenthood       PG-13  20000000.0
# 9        10                        Lethal Weapon 2           R  25000000.0
# 10       11                   The War of the Roses           R  26000000.0
# ...

# %%
movies.tail()
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 615           NaN          NaN        NaN      NaN     NaN           NaN
#
#     Summary
# 611     NaN
# 612     NaN
# 613     NaN
# ...

# %%
movies.tail(10)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 606      607              Spider-Man: Far from Home       PG-13  160000000.0
# 607      608                                  Dumbo          PG  170000000.0
# 608      609                         Captain Marvel       PG-13  175000000.0
# 609      610                                Aladdin          PG  183000000.0
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# ...

# %%
movies.tail(19)
# Out:
#      MovieID                                       Title MPAA Rating  \
# 597      598                                  The Upside       PG-13
# 598      599           John Wick: Chapter 3 - Parabellum           R
# 599      600                             It: Chapter Two           R
# 600      601                   The Secret Life of Pets 2          PG
# 601      602               Once Upon a Time in Hollywood           R
# 602      603           The LEGO Movie 2: The Second Part          PG
# 603      604                                     Shazam!       PG-13
# 604      605  How to Train Your Dragon: The Hidden World          PG
# 605      606                   Pokemon Detective Pikachu          PG
# 606      607                   Spider-Man: Far from Home       PG-13
# 607      608                                       Dumbo          PG
# 608      609                              Captain Marvel       PG-13
# 609      610                                     Aladdin          PG
# ...

# %%
movies.shape
# Out:
# (616, 11)

# %%
movies.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
movies.isna()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
movies.isna().sum()
# Out:
# MovieID           0
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
movies.isnull()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
movies.drop(labels=["Summary"], axis=1)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
movies.drop(labels=["Budget"], axis=1)
# Out:
#      MovieID                                  Title MPAA Rating         Gross  \
# 0          1                     Look Who's Talking       PG-13  2.960000e+08
# 1          2                     Driving Miss Daisy          PG  1.457933e+08
# 2          3                         Turner & Hooch          PG  7.107992e+07
# 3          4             Born on the Fourth of July           R  1.610017e+08
# 4          5                        Field of Dreams          PG  8.443162e+07
# ..       ...                                    ...         ...           ...
# 611      612                            Toy Story 4           G  1.062000e+09
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  7.594000e+08
# 613      614                          The Lion King          PG  1.632000e+09
# 614      615                      Avengers: Endgame       PG-13  2.796000e+09
# 615        0                                    NaN         NaN           NaN
#
# ...

# %%
 movies.drop(labels=[615], axis=0, inplace=True)

# %%
movies.shape
# Out:
# (615, 11)

# %%
movies.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
movies["Budget"].astype("int", copy=False)
# Out:
# 0        7500000
# 1        7500000
# 2       13000000
# 3       14000000
# 4       15000000
#          ...
# 610    200000000
# 611    200000000
# 612    200000000
# 613    250000000
# 614    356000000
# Name: Budget, Length: 615, dtype: int64

# %%
movies["Budget"] = movies["Budget"].astype("int")

# %%
movies.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget            int64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
movies["Release Date"] = pd.to_datetime(movies["Release Date"], format='%Y-%m-%d', errors='ignore')

# %%
movies[movies["Gross"] > 50000000]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
movies[movies["Gross"] > 100000]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
movies[movies["Gross"] > 60000000]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
movies[movies["Genre"] == "Thriller"]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 28        29                                  Ghost       PG-13   22000000
# 32        33               The Hunt for Red October          PG   30000000
# 39        40                             Die Hard 2           R   70000000
# 76        77                          Patriot Games           R   45000000
# 77        78                         Basic Instinct           R   49000000
# 92        93                             Rising Sun           R   40000000
# 98        99                      Jurassic Park III       PG-13   93000000
# 99       100                           Pulp Fiction           R    8000000
# 115      116               Clear and Present Danger       PG-13   62000000
# 131      132                           Crimson Tide           R   53000000
# 136      137             Die Hard: With a Vengeance           R   90000000
# ...

# %%
movies[movies["Genre"] == "Comedy"]
# Out:
#      MovieID                          Title MPAA Rating     Budget  \
# 1          2             Driving Miss Daisy          PG    7500000
# 8          9                     Parenthood       PG-13   20000000
# 9         10                Lethal Weapon 2           R   25000000
# 10        11           The War of the Roses           R   26000000
# 14        15                Ghostbusters II          PG   37000000
# ..       ...                            ...         ...        ...
# 516      517                Pitch Perfect 2       PG-13   29000000
# 537      538                       Deadpool           R   58000000
# 582      583                     Deadpool 2           R  110000000
# 597      598                     The Upside       PG-13   37500000
# 601      602  Once Upon a Time in Hollywood           R   96000000
#
#            Gross Release Date   Genre  Runtime  Rating  Rating Count  \
# 1    145793296.0   1989-12-13  Comedy     99.0     7.4       91075.0
# ...

# %%
movies[(movies["Genre"] == "Action") | (movies["Genre"] == "Thriller") & (movies["Rating"] > 7)]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 11        12  National Lampoon's Christmas Vacation       PG-13   27000000
# 13        14                                 Batman          PG   35000000
# 18        19                           Tango & Cash           R   55000000
# 21        22           Teenage Mutant Ninja Turtles          PG   13500000
# 23        24                       Kindergarten Cop       PG-13   15000000
# ..       ...                                    ...         ...        ...
# 594      595                 Avengers: Infinity War       PG-13  400000000
# 603      604                                Shazam!       PG-13  100000000
# 606      607              Spider-Man: Far from Home       PG-13  160000000
# 608      609                         Captain Marvel       PG-13  175000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
movies[(movies["Genre"] == "Action") & (movies["Rating"] > 7)]
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 11        12  National Lampoon's Christmas Vacation       PG-13   27000000
# 13        14                                 Batman          PG   35000000
# 45        46        Teenage Mutant Ninja Turtles II          PG   25000000
# 73        74               The Last of the Mohicans           R   40000000
# 104      105                                  Speed           R   30000000
# 118      119                              True Lies           R  115000000
# 127      128                                  Se7en           R   33000000
# 133      134                              GoldenEye       PG-13   58000000
# 135      136                             Braveheart           R   72000000
# 150      151                               The Rock           R   75000000
# 152      153                    Mission: Impossible       PG-13   80000000
# ...

# %%
#show the movies with more than 7 in Rating & greater than 50 million Gross & with Parental guidance as MPAA Rating
movies[(movies["Gross"] > 50000000) & (movies["MPAA Rating"] == "Parental guidance") & (movies["Rating"] > 7)]
# Out:
# Empty DataFrame
# Columns: [MovieID, Title, MPAA Rating, Budget, Gross, Release Date, Genre, Runtime, Rating, Rating Count, Summary]
# Index: []

# %%
#count of Animation movies with more than 7 in Rating (use the shape function)
#movies.shape I could't use the shape function for this. HELPPPPP
movies[(movies["Genre"] == "Animation") & (movies["Rating"] > 7)].shape[0]
# Out:
# 39

# %%
#show the list of top 5 movies based on Budget
movies.head()
# Out:
#    MovieID                       Title MPAA Rating    Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000  145793296.0
# 2        3              Turner & Hooch          PG  13000000   71079915.0
# 3        4  Born on the Fourth of July           R  14000000  161001698.0
# 4        5             Field of Dreams          PG  15000000   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
movies
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
movie_sorted_by_budget = movies.sort_values(by=["Budget"], ascending=False)

# %%
movie_sorted_by_budget.head()
# Out:
#      MovieID                                        Title MPAA Rating  \
# 594      595                       Avengers: Infinity War       PG-13
# 454      455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614      615                            Avengers: Endgame       PG-13
# 574      575                     Star Wars: The Last Jedi       PG-13
# 375      376     Pirates of the Caribbean: At World's End       PG-13
#
#         Budget         Gross Release Date            Genre  Runtime  Rating  \
# 594  400000000  2.048000e+09   2018-04-23           Action    149.0     NaN
# 454  380000000  1.045714e+09   2011-05-14           Action    136.0     6.6
# 614  356000000  2.796000e+09   2019-04-22           Action    181.0     NaN
# 574  317000000  1.333000e+09   2019-12-09  Science Fiction    152.0     NaN
# 375  300000000  9.610000e+08   2007-05-19        Adventure    169.0     7.1
#
#      Rating Count                                            Summary
# ...

# %%
#show the top 5 Comedy movies by Rating
movies.head()
# Out:
#    MovieID                       Title MPAA Rating    Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000  145793296.0
# 2        3              Turner & Hooch          PG  13000000   71079915.0
# 3        4  Born on the Fourth of July           R  14000000  161001698.0
# 4        5             Field of Dreams          PG  15000000   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
movie_sorted_by_Rating = movies.sort_values(by=["Rating"])

# %%
movie_sorted_by_Rating
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 426      427                     The Last Airbender          PG  150000000
# 278      279                Spy Kids 3-D: Game Over          PG   38000000
# 438      439   Alvin and the Chipmunks: Chipwrecked           G   75000000
# 413      414                                   2012       PG-13  200000000
# 227      228         Nutty Professor II: The Klumps       PG-13   84000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
list_of_index_rating_NaN = movie_sorted_by_Rating[movie_sorted_by_Rating["Rating"].isna() == True].index

# %%
movie_sorted_by_Rating.drop(labels=list_of_index_rating_NaN, inplace=True)

# %%
movie_sorted_by_Rating
# Out:
#      MovieID                                          Title MPAA Rating  \
# 426      427                             The Last Airbender          PG
# 278      279                        Spy Kids 3-D: Game Over          PG
# 438      439           Alvin and the Chipmunks: Chipwrecked           G
# 413      414                                           2012       PG-13
# 227      228                 Nutty Professor II: The Klumps       PG-13
# ..       ...                                            ...         ...
# 98        99                              Jurassic Park III       PG-13
# 83        84                               Schindler's List           R
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 393      394                                The Dark Knight       PG-13
#
#         Budget         Gross Release Date      Genre  Runtime  Rating  \
# ...

# %%
movie_sorted_by_Rating.tail()
# Out:
#      MovieID                                          Title MPAA Rating  \
# 98        99                              Jurassic Park III       PG-13
# 83        84                               Schindler's List           R
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 393      394                                The Dark Knight       PG-13
#
#         Budget         Gross Release Date     Genre  Runtime  Rating  \
# 98    93000000  3.688000e+08   2001-07-16  Thriller     92.0     8.9
# 83    22000000  3.213656e+08   1993-11-29   History    195.0     8.9
# 287   94000000  1.118889e+09   2003-12-01   Fantasy    201.0     8.9
# 99     8000000  2.139288e+08   1994-09-10  Thriller    154.0     8.9
# 393  185000000  1.004558e+09   2008-07-16    Action    152.0     9.0
#
#      Rating Count                                            Summary
# ...

# %%
movie_sorted_by_Rating[movie_sorted_by_Rating["Genre"] == "Comedy"].head(5)
# Out:
#      MovieID                           Title MPAA Rating     Budget  \
# 227      228  Nutty Professor II: The Klumps       PG-13   84000000
# 244      245                  Dr. Dolittle 2          PG   70000000
# 338      339                   Scary Movie 4       PG-13   45000000
# 397      398            Paul Blart: Mall Cop          PG   26000000
# 423      424                  Little Fockers       PG-13  100000000
#
#            Gross Release Date   Genre  Runtime  Rating  Rating Count  \
# 227  123307945.0   2000-07-27  Comedy    106.0     4.4       46222.0
# 244  176104344.0   2001-06-22  Comedy     87.0     4.7       39656.0
# 338  178262620.0   2006-04-13  Comedy     83.0     5.0      108367.0
# 397  183293131.0   2009-01-15  Comedy     91.0     5.2       97379.0
# 423  310650585.0   2010-12-21  Comedy     98.0     5.5      100845.0
#
#                                                Summary
# 227  Scientist Sherman Klumps inventions, his upcom...
# ...

# %%
#top 5 movie names by Rating
movie_sorted_by_Rating.head(5)
# Out:
#      MovieID                                 Title MPAA Rating     Budget  \
# 426      427                    The Last Airbender          PG  150000000
# 278      279               Spy Kids 3-D: Game Over          PG   38000000
# 438      439  Alvin and the Chipmunks: Chipwrecked           G   75000000
# 413      414                                  2012       PG-13  200000000
# 227      228        Nutty Professor II: The Klumps       PG-13   84000000
#
#            Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 426  318502923.0   2010-06-30  Adventure    103.0     4.1      139750.0
# 278  197011982.0   2003-07-25     Family     84.0     4.2       50809.0
# 438  342695435.0   2011-12-14     Family     87.0     4.3       28949.0
# 413  769653595.0   2009-10-10  Adventure    158.0     4.3       28949.0
# 227  123307945.0   2000-07-27     Comedy    106.0     4.4       46222.0
#
#                                                Summary
# ...

# %%
movie_sorted_by_Rating.tail(5)
# Out:
#      MovieID                                          Title MPAA Rating  \
# 98        99                              Jurassic Park III       PG-13
# 83        84                               Schindler's List           R
# 287      288  The Lord of the Rings: The Return of the King       PG-13
# 99       100                                   Pulp Fiction           R
# 393      394                                The Dark Knight       PG-13
#
#         Budget         Gross Release Date     Genre  Runtime  Rating  \
# 98    93000000  3.688000e+08   2001-07-16  Thriller     92.0     8.9
# 83    22000000  3.213656e+08   1993-11-29   History    195.0     8.9
# 287   94000000  1.118889e+09   2003-12-01   Fantasy    201.0     8.9
# 99     8000000  2.139288e+08   1994-09-10  Thriller    154.0     8.9
# 393  185000000  1.004558e+09   2008-07-16    Action    152.0     9.0
#
#      Rating Count                                            Summary
# ...

# %%
movies
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...

# %%
#top 3 high Gross Romance movies released after 1999, not included (typecast it to datetime)

romance_movies = movies[(movies["Genre"] == "Romance")]
romance_movies["Year"] = romance_movies["Release Date"].dt.year
romance_movies_after_1999 = romance_movies[romance_movies["Year"] > 1999]
romance_movies_after_1999.sort_values(by="Gross", ascending=False).head(3)
# Out:
# /var/folders/1j/30cgkc_x275_pj48vlh0dgz00000gn/T/ipykernel_1396/593081762.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   romance_movies["Year"] = romance_movies["Release Date"].dt.year
#      MovieID                                      Title MPAA Rating  \
# 464      465  The Twilight Saga: Breaking Dawn - Part 2       PG-13
# 442      443  The Twilight Saga: Breaking Dawn - Part 1       PG-13
# 401      402                The Twilight Saga: New Moon       PG-13
#
#         Budget        Gross Release Date    Genre  Runtime  Rating  \
# 464  120000000  829000000.0   2012-11-13  Romance    115.0     5.5
# 442  110000000  712171856.0   2011-03-15  Romance    117.0     4.9
# ...

# %%
#how many Genres are present in the dataframe? (use the function value_counts() which applies to Series, not Dataframe)
genres_serie = movies["Genre"]
genres_value_count = genres_serie.value_counts()
genres_value_count.size
# Out:
# 16

# %%
#top 5 expensive movies released after 1999, not included (measured by Budget)
movies
# Out:
#      MovieID                                  Title MPAA Rating     Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000
# 1          2                     Driving Miss Daisy          PG    7500000
# 2          3                         Turner & Hooch          PG   13000000
# 3          4             Born on the Fourth of July           R   14000000
# 4          5                        Field of Dreams          PG   15000000
# ..       ...                                    ...         ...        ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000
# 611      612                            Toy Story 4           G  200000000
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000
# 613      614                          The Lion King          PG  250000000
# 614      615                      Avengers: Endgame       PG-13  356000000
#
# ...
